# %%
import pandas as pd

# %%
 df = pd.read_csv("C:\\Users\\lenovo\\final\\ga_hits.csv")

# %%
df.shape
# Out:
# (15726470, 11)

# %%
df.head()
# Out:
#                                   session_id    hit_date  hit_time  \
# 0  5639623078712724064.1640254056.1640254056  2021-12-23  597864.0
# 1  7750352294969115059.1640271109.1640271109  2021-12-23  597331.0
# 2   885342191847998240.1640235807.1640235807  2021-12-23  796252.0
# 3   142526202120934167.1640211014.1640211014  2021-12-23  934292.0
# 4  3450086108837475701.1640265078.1640265078  2021-12-23  768741.0
#
#    hit_number hit_type hit_referer  \
# 0          30    event         NaN
# 1          41    event         NaN
# 2          49    event         NaN
# 3          46    event         NaN
# 4          79    event         NaN
#
#                                        hit_page_path event_category  \
# 0  sberauto.com/cars?utm_source_initial=google&ut...           quiz
# 1  sberauto.com/cars/fiat?city=1&city=18&rental_c...           quiz
# 2  sberauto.com/cars/all/volkswagen/polo/e994838f...           quiz
# 3  sberauto.com/cars?utm_source_initial=yandex&ut...           quiz
# ...

# %%
df.drop_duplicates()
# Out:
#           Unnamed: 0                                 session_id    hit_date  \
# 0                  0  5639623078712724064.1640254056.1640254056  2021-12-23
# 1                  1  7750352294969115059.1640271109.1640271109  2021-12-23
# 2                  2   885342191847998240.1640235807.1640235807  2021-12-23
# 3                  3   142526202120934167.1640211014.1640211014  2021-12-23
# 4                  4  3450086108837475701.1640265078.1640265078  2021-12-23
# ...              ...                                        ...         ...
# 15726465    15726465  6866159858916559617.1640270865.1640270865  2021-12-23
# 15726466    15726466  7310304587364460692.1640261783.1640261783  2021-12-23
# 15726467    15726467  8013702685784312179.1640270195.1640270195  2021-12-23
# 15726468    15726468  8021505554734405918.1640257821.1640257821  2021-12-23
# 15726469    15726469  1569014437485249865.1640269129.1640269129  2021-12-23
#
# ...

# %%
df.isna().sum()
# Out:
# session_id               0
# hit_date                 0
# hit_time           9160322
# hit_number               0
# hit_type                 0
# hit_referer        6274804
# hit_page_path            0
# event_category           0
# event_action             0
# event_label        3760184
# event_value       15726470
# dtype: int64

# %%
df = df.drop(columns=['event_value', 'event_label', 'hit_time', 'hit_referer', 'hit_number', 'event_category'])

# %%
df.shape
# Out:
# (15726470, 5)

# %%
df.head()
# Out:
#                                   session_id    hit_date hit_type  \
# 0  5639623078712724064.1640254056.1640254056  2021-12-23    event
# 1  7750352294969115059.1640271109.1640271109  2021-12-23    event
# 2   885342191847998240.1640235807.1640235807  2021-12-23    event
# 3   142526202120934167.1640211014.1640211014  2021-12-23    event
# 4  3450086108837475701.1640265078.1640265078  2021-12-23    event
#
#                                        hit_page_path event_action
# 0  sberauto.com/cars?utm_source_initial=google&ut...    quiz_show
# 1  sberauto.com/cars/fiat?city=1&city=18&rental_c...    quiz_show
# 2  sberauto.com/cars/all/volkswagen/polo/e994838f...    quiz_show
# 3  sberauto.com/cars?utm_source_initial=yandex&ut...    quiz_show
# 4  sberauto.com/cars/all/mercedes-benz/cla-klasse...    quiz_show

# %%
target_list = ['sub_car_claim_click', 'sub_car_claim_submit_click',
'sub_open_dialog_click', 'sub_custom_question_submit_click',
'sub_call_number_click', 'sub_callback_submit_click', 'sub_submit_success',
'sub_car_request_submit_click']

# %%
df['target'] = df['event_action'].apply(lambda x: 1 if x in target_list else 0)

# %%
df.to_csv('C:\\Users\\lenovo\\final\\df')

# %%
df_session = pd.read_csv('C:\\Users\\lenovo\\final\\ga_sessions.csv')
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_19424\3720221076.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_session = pd.read_csv('C:\\Users\\lenovo\\final\\ga_sessions.csv')

# %%
df_session.head()
# Out:
#                                   session_id          client_id  visit_date  \
# 0  9055434745589932991.1637753792.1637753792  2108382700.163776  2021-11-24
# 1   905544597018549464.1636867290.1636867290   210838531.163687  2021-11-14
# 2  9055446045651783499.1640648526.1640648526  2108385331.164065  2021-12-28
# 3  9055447046360770272.1622255328.1622255328  2108385564.162225  2021-05-29
# 4  9055447046360770272.1622255345.1622255345  2108385564.162225  2021-05-29
#
#   visit_time  visit_number            utm_source utm_medium  \
# 0   14:36:32             1  ZpYIoDJMcFzVoPFsHGJL     banner
# 1   08:21:30             1  MvfHsxITijuriZxsqZqt        cpm
# 2   02:42:06             1  ZpYIoDJMcFzVoPFsHGJL     banner
# 3   05:00:00             1  kjsLglQLzykiRbcDiGcD        cpc
# 4   05:00:00             2  kjsLglQLzykiRbcDiGcD        cpc
#
#            utm_campaign         utm_adcontent           utm_keyword  \
# 0  LEoPHuyFvzoNfnzGgfcd  vCIpmpaGBnIQhyYNkXqp  puhZPIYqKXeFPaUviSjo
# ...

# %%
df_session.shape
# Out:
# (1860042, 18)

# %%
df_session.drop_duplicates()
# Out:
#                                         session_id          client_id  \
# 0        9055434745589932991.1637753792.1637753792  2108382700.163776
# 1         905544597018549464.1636867290.1636867290   210838531.163687
# 2        9055446045651783499.1640648526.1640648526  2108385331.164065
# 3        9055447046360770272.1622255328.1622255328  2108385564.162225
# 4        9055447046360770272.1622255345.1622255345  2108385564.162225
# ...                                            ...                ...
# 1860037  9055415581448263752.1640159305.1640159305  2108378238.164016
# 1860038  9055421130527858185.1622007305.1622007305  2108379530.162201
# 1860039  9055422955903931195.1636979515.1636979515  2108379955.163697
# 1860040   905543020766873816.1638189404.1638189404   210838164.163819
# 1860041  9055430416266113553.1640968742.1640968742  2108381692.164097
#
#          visit_date            utm_source utm_medium          utm_campaign  \
# ...

# %%
df_session.isna().sum()
# Out:
# session_id                        0
# client_id                         0
# visit_date                        0
# visit_time                        0
# visit_number                      0
# utm_source                       97
# utm_medium                        0
# utm_campaign                 219603
# utm_adcontent                335615
# utm_keyword                 1082061
# device_category                   0
# device_os                   1070138
# device_brand                 367178
# device_model                1843704
# device_screen_resolution          0
# device_browser                    0
# geo_country                       0
# geo_city                          0
# dtype: int64

# %%
df_session = df_session.drop(['device_model', 'visit_time', 'visit_number', 'device_browser', 'device_screen_resolution'], axis=1)

# %%
df_session.head()
# Out:
#                                   session_id          client_id  visit_date  \
# 0  9055434745589932991.1637753792.1637753792  2108382700.163776  2021-11-24
# 1   905544597018549464.1636867290.1636867290   210838531.163687  2021-11-14
# 2  9055446045651783499.1640648526.1640648526  2108385331.164065  2021-12-28
# 3  9055447046360770272.1622255328.1622255328  2108385564.162225  2021-05-29
# 4  9055447046360770272.1622255345.1622255345  2108385564.162225  2021-05-29
#
#              utm_source utm_medium          utm_campaign  \
# 0  ZpYIoDJMcFzVoPFsHGJL     banner  LEoPHuyFvzoNfnzGgfcd
# 1  MvfHsxITijuriZxsqZqt        cpm  FTjNLDyTrXaWYgZymFkV
# 2  ZpYIoDJMcFzVoPFsHGJL     banner  LEoPHuyFvzoNfnzGgfcd
# 3  kjsLglQLzykiRbcDiGcD        cpc                   NaN
# 4  kjsLglQLzykiRbcDiGcD        cpc                   NaN
#
#           utm_adcontent           utm_keyword device_category device_os  \
# 0  vCIpmpaGBnIQhyYNkXqp  puhZPIYqKXeFPaUviSjo          mobile   Android
# ...

# %%
df_all = pd.merge(left=df.groupby('session_id')['target'].max(), right=df_session, on='session_id', how='left')

# %%
df_all.shape
# Out:
# (1734610, 14)

# %%
df_all.to_csv('C:\\Users\\lenovo\\final\\all')
